# %%
import FinanceDataReader as fdr
import pandas as pd
import numpy as np
s1 = fdr.DataReader('267250', start = '2023', end = '2024')
df1 = pd.DataFrame(s1)
df1 = df1.dropna()
df1.to_csv('HD현대 확인용.csv')

# %%
import FinanceDataReader as fdr
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from keras.layers import Dense, Activation
from keras.layers import LSTM
from keras.models import Sequential
# Open, High, Low, Close, Volume, Change
resultdf = pd.DataFrame(columns=['시가','최고가','최저가','종가','판매량','변동률','추가열'])
max_num = 1# 사용할 특성열 수
col_list = ['OmH']
selected_list = []
start_col_num = 0
for i in col_list:
            s1 = fdr.DataReader('010130', start = '1960', end = '2023')
            df1 = pd.DataFrame(s1)
            df1 = df1.dropna()
    # for j in col_list[71:]:
    # for j in col_list[start_col_num+1:]:
        # for a in col_list[start_col_num+2:]:
        # for a in col_list[43:]:
            selected_list.append(i)
            # selected_list.append(j)
            # selected_list.append(a)
            print(i)
            if len(selected_list) == max_num:
                for k in selected_list:
                    if k == 'DPR':
                        df1['DPR'] = df1['High'] - df1['Low']
                    elif k == 'IPC':
                        df1['IPC'] = df1['Open'] - df1['Close']
                    elif k == 'VWCP':
                        df1['VWCP'] = df1['Volume'] * df1['Change']
                    elif k == 'IPRPV':
                        if 'DPR' in selected_list:
                            df1['IPRPV'] = df1['DPR']/df1['Volume']
                        else:
                            break
                    elif k == 'OMH':
                        df1['OMH'] = df1['Open'] - df1['High']
                    elif k == 'OML':
                        df1['OML'] = df1['Open'] - df1['Low']
                    elif k == 'OMV':
                        df1['OMV'] = df1['Open'] - df1['Volume']
                    elif k == 'OMC':
                        df1['OMC'] = df1['Open'] - df1['Change']
                    elif k == 'HMO':
                        df1['HMO'] = df1['High'] - df1['Open']
                    elif k == 'HMC':
                        df1['HMC'] = df1['High'] - df1['Close']
                    elif k == 'HMV':
                        df1['HMV'] = df1['High'] - df1['Volume']
                    elif k == 'HMCh':
                        df1['HMCh'] = df1['High'] - df1['Change']
                    elif k == 'LMO':
                        df1['LMO'] = df1['Low'] - df1['Open']
                    elif k == 'LMH':
                        df1['LMH'] = df1['Low'] - df1['High']
                    elif k == 'LMC':
                        df1['LMC'] = df1['Low'] - df1['Close']
                    elif k == 'LMV':
                        df1['LMV'] = df1['Low'] - df1['Volume']
                    elif k == 'LMCh':
                        df1['LMCh'] = df1['Low'] - df1['Change']
                    elif k == 'CMO':
                        df1['CMO'] = df1['Close'] - df1['Open']
                    elif k == 'CMH':
                        df1['CMH'] = df1['Close'] - df1['High']
                    elif k == 'CML':
                        df1['CML'] = df1['Close'] - df1['Low']
                    elif k == 'CMV':
                        df1['CMV'] = df1['Close'] - df1['Volume']
                    elif k == 'CMCh':
                        df1['CMCh'] = df1['Close'] - df1['Change']
                    elif k == 'VMO':
                        df1['VMO'] = df1['Volume'] - df1['Open']
                    elif k == 'VMH':
                        df1['VMH'] = df1['Volume'] - df1['High']
                    elif k == 'VML':
                        df1['VML'] = df1['Volume'] - df1['Low']
                    elif k == 'VMC':
                        df1['VMC'] = df1['Volume'] - df1['Close']
                    elif k == 'VMCh':
                        df1['VMCh'] = df1['Volume'] - df1['Change']
                    elif k == 'ChMO':
                        df1['ChMO'] = df1['Change'] - df1['Open']
                    elif k == 'ChMH':
                        df1['ChMH'] = df1['Change'] - df1['High']
                    elif k == 'ChML':
                        df1['ChML'] = df1['Change'] - df1['Low']
                    elif k == 'ChMC':
                        df1['ChMC'] = df1['Change'] - df1['Close']
                    elif k == 'ChMV':
                        df1['ChMV'] = df1['Change'] - df1['Volume']
                    elif k == 'OPH':
                        df1['OPH'] = df1['Open'] + df1['High']
                    elif k == 'OPL':
                        df1['OPL'] = df1['Open'] + df1['Low']
                    elif k == 'OPC':
                        df1['OPC'] = df1['Open'] + df1['Close']
                    elif k == 'OPV':
                        df1['OPV'] = df1['Open'] + df1['Volume']
                    elif k == 'OPCh':
                        df1['OPCh'] = df1['Open'] + df1['Change']
                    elif k == 'HPO':
                        df1['HPO'] = df1['High'] + df1['Open']
                    elif k == 'HPC':
                        df1['HPC'] = df1['High'] + df1['Close']
                    elif k == 'HPV':
                        df1['HPV'] = df1['High'] + df1['Volume']
                    elif k == 'HPL':
                        df1['HPL'] = df1['High'] + df1['Low']
                    elif k == 'HPCh':
                        df1['HPCh'] = df1['High'] + df1['Change']
                    elif k == 'LPO':
                        df1['LPO'] = df1['Low'] + df1['Open']
                    elif k == 'LPH':
                        df1['LPH'] = df1['Low'] + df1['High']
                    elif k == 'LPC':
                        df1['LPC'] = df1['Low'] + df1['Close']
                    elif k == 'LPV':
                        df1['LPV'] = df1['Low'] + df1['Volume']
                    elif k == 'LPCh':
                        df1['LPCh'] = df1['Low'] + df1['Change']
                    elif k == 'CPO':
                        df1['CPO'] = df1['Close'] + df1['Open']
                    elif k == 'CPH':
                        df1['CPH'] = df1['Close'] + df1['High']
                    elif k == 'CPL':
                        df1['CPL'] = df1['Close'] + df1['Low']
                    elif k == 'CPV':
                        df1['CPV'] = df1['Close'] + df1['Volume']
                    elif k == 'CPCh':
                        df1['CPCh'] = df1['Close'] + df1['Change']
                    elif k == 'VPO':
                        df1['VPO'] = df1['Volume'] + df1['Open']
                    elif k == 'VPH':
                        df1['VPH'] = df1['Volume'] + df1['High']
                    elif k == 'VPL':
                        df1['VPL'] = df1['Volume'] + df1['Low']
                    elif k == 'VPC':
                        df1['VPC'] = df1['Volume'] + df1['Close']
                    elif k == 'VPCh':
                        df1['VPCh'] = df1['Volume'] + df1['Change']
                    elif k == 'ChPO':
                        df1['ChPO'] = df1['Change'] + df1['Open']
                    elif k == 'ChPH':
                        df1['ChPH'] = df1['Change'] + df1['High']
                    elif k == 'ChPL':
                        df1['ChPL'] = df1['Change'] + df1['Low']
                    elif k == 'ChPC':
                        df1['ChPC'] = df1['Change'] + df1['Close']
                    elif k == 'ChPV':
                        df1['ChPV'] = df1['Change'] + df1['Volume']
                    elif k == 'ODH':
                        df1['ODH'] = df1['Open'] / df1['High']
                    elif k == 'ODL':
                        df1['ODL'] = df1['Open'] / df1['Low']
                    elif k == 'ODC':
                        df1['ODC'] = df1['Open'] / df1['Close']
                    elif k == 'ODV':
                        df1['ODV'] = df1['Open'] / df1['Volume']
                    elif k == 'HDO':
                        df1['HDO'] = df1['High'] / df1['Open']
                    elif k == 'HDL':
                        df1['HDL'] = df1['High'] / df1['Low']
                    elif k == 'HDC':
                        df1['HDC'] = df1['High'] / df1['Close']
                    elif k == 'HDV':
                        df1['HDV'] = df1['High'] / df1['Volume']
                    elif k == 'LDO':
                        df1['LDO'] = df1['Low'] / df1['Open']
                    elif k == 'LDH':
                        df1['LDH'] = df1['Low'] / df1['High']
                    elif k == 'LDC':
                        df1['LDC'] = df1['Low'] / df1['Close']
                    elif k == 'LDV':
                        df1['LDV'] = df1['Low'] / df1['Volume']
                    elif k == 'VDO':
                        df1['VDO'] = df1['Volume'] / df1['Open']
                    elif k == 'VDH':
                        df1['VDH'] = df1['Volume'] / df1['High']
                    elif k == 'VDL':
                        df1['VDL'] = df1['Volume'] / df1['Low']
                    elif k == 'VDC':
                        df1['VDC'] = df1['Volume'] / df1['Close']
                    elif k == 'ChDO':
                        df1['ChDO'] = df1['Change'] / df1['Open']
                    elif k == 'ChDH':
                        df1['ChDH'] = df1['Change'] / df1['High']
                    elif k == 'ChDL':
                        df1['ChDL'] = df1['Change'] / df1['Low']
                    elif k == 'ChDC':
                        df1['ChDC'] = df1['Change'] / df1['Close']
                    elif k == 'ChDV':
                        df1['ChDV'] = df1['Change'] / df1['Volume']
                    elif k == 'OmH':
                        df1['OmH'] = df1['Open'] * df1['High']
                    elif k == 'OmL':
                        df1['OmL'] = df1['Open'] * df1['Low']
                    elif k == 'OmC':
                        df1['OmC'] = df1['Open'] * df1['Close']
                    elif k == 'OmV':
                        df1['OmV'] = df1['Open'] * df1['Volume']
                    elif k == 'OmCh':
                        df1['OmCh'] = df1['Open'] * df1['Change']
                    elif k == 'HmC':
                        df1['HmC'] = df1['High'] * df1['Close']
                    elif k == 'HmV':
                        df1['HmV'] = df1['High'] * df1['Volume']
                    elif k == 'HmCh':
                        df1['HmCh'] = df1['High'] * df1['Change']
                    elif k == 'LmH':
                        df1['LmH'] = df1['Low'] * df1['High']
                    elif k == 'LmC':
                        df1['LmC'] = df1['Low'] * df1['Close']
                    elif k == 'LmV':
                        df1['LmV'] = df1['Low'] * df1['Volume']
                    elif k == 'LmCh':
                        df1['LmCh'] = df1['Low'] * df1['Change']
                    elif k == 'CmV':
                        df1['CmV'] = df1['Close'] * df1['Volume']
                    elif k == 'CmCh':
                        df1['CmCh'] = df1['Close'] * df1['Change']
                    elif k == 'VmCh':
                        df1['VmCh'] = df1['Volume'] * df1['Change']
                df1.to_csv('sk.csv')
                # CSV 파일을 불러옵니다.
                data = pd.read_csv('sk.csv')

                # 날짜(Dates) 열을 Datetime 형식으로 변환합니다.
                data['Date'] = pd.to_datetime(data['Date'])

                # 필요한 열을 추출합니다. (이 예에서는 'Open', 'High', 'Low', 'Close', 'Volume', 'Change' 열을 사용)
                use_list = ['Open', 'High', 'Low', 'Close', 'Volume', 'Change']
                for b in selected_list:
                    use_list.append(b)
                print(use_list)
                features = data[use_list]
                unit_num = len(use_list)

                # Min-Max 스케일링을 사용하여 데이터를 정규화합니다.
                scaler = MinMaxScaler()
                features_normalized = scaler.fit_transform(features)

                # 시계열 예측을 위해 데이터를 X와 y로 분리합니다.
                # X는 어제의 데이터, y는 오늘의 'Open', 'High', 'Low', 'Close', 'Volume', 'Change' 값을 나타냅니다.
                X, y = [], []

                look_back = 1  # 어제의 데이터를 사용
                for c in range(look_back, len(features_normalized)):
                    X.append(features_normalized[c - look_back:c])
                    y.append(features_normalized[c])

                X, y = np.array(X), np.array(y)

                # 데이터를 훈련 세트와 테스트 세트로 나눕니다.
                split_ratio = 0.8  # 예시로 80%를 훈련 데이터로 사용
                split_index = int(split_ratio * len(X))

                X_train, X_test = X[:split_index], X[split_index:]
                y_train, y_test = y[:split_index], y[split_index:]

                # 모델 생성
                model = Sequential()

                model.add(LSTM(
                    units=100,
                    input_shape=(X_train.shape[1], X_train.shape[2]),
                    return_sequences=True))
                model.add(LSTM(
                    100,
                    return_sequences=False))
                model.add(Dense(units=unit_num))  # 'Open', 'High', 'Low', 'Close', 'Volume', 'Change'에 대한 출력
                model.add(Activation('linear'))

                # 모델 컴파일
                model.compile(loss='mse', optimizer='adam')

                # 모델 학습
                model.fit(X_train, y_train, epochs=50, batch_size=64, validation_split=0.1)

                # 예측
                # 시가, 최고가, 최저가, 종가, 판매량,변동률
                user_input = [49200,49450,43600,44200,1364686,-0.105263158]
                for l in selected_list:
                    if l == 'DPR':
                        user_input.append(user_input[1]-user_input[2])
                    elif l == 'IPC':
                        user_input.append(user_input[0]-user_input[3])
                    elif l == 'VWCP':
                        user_input.append(user_input[4]*user_input[5])
                    elif l == 'IPRPV':
                        if 'DPR' in selected_list:
                            user_input.append(user_input[6]/user_input[4])
                    elif l == 'OMH':
                        user_input.append(user_input[0]-user_input[1])
                    elif l == 'OML':
                        user_input.append(user_input[0]-user_input[2])
                    elif l == 'OMV':
                        user_input.append(user_input[0]-user_input[4])
                    elif l == 'OMC':
                        user_input.append(user_input[0]-user_input[5])
                    elif l == 'HMO':
                        user_input.append(user_input[1]-user_input[0])
                    elif l == 'HMC':
                        user_input.append(user_input[1]-user_input[3])
                    elif l == 'HMV':
                        user_input.append(user_input[1]-user_input[4])
                    elif l == 'HMCh':
                        user_input.append(user_input[1]-user_input[5])
                    elif l == 'LMO':
                        user_input.append(user_input[2]-user_input[0])
                    elif l == 'LMH':
                        user_input.append(user_input[2]-user_input[1])
                    elif l == 'LMC':
                        user_input.append(user_input[2]-user_input[3])
                    elif l == 'LMV':
                        user_input.append(user_input[2]-user_input[4])
                    elif l == 'LMCh':
                        user_input.append(user_input[2]-user_input[5])
                    elif l == 'CMO':
                        user_input.append(user_input[3]-user_input[0])
                    elif l == 'CMH':
                        user_input.append(user_input[3]-user_input[1])
                    elif l == 'CML':
                        user_input.append(user_input[3]-user_input[2])
                    elif l == 'CMV':
                        user_input.append(user_input[3]-user_input[4])
                    elif l == 'CMCh':
                        user_input.append(user_input[3]-user_input[5])
                    elif l == 'VMO':
                        user_input.append(user_input[4]-user_input[0])
                    elif l == 'VMH':
                        user_input.append(user_input[4]-user_input[1])
                    elif l == 'VML':
                        user_input.append(user_input[4]-user_input[2])
                    elif l == 'VMC':
                        user_input.append(user_input[4]-user_input[3])
                    elif l == 'VMCh':
                        user_input.append(user_input[4]-user_input[5])
                    elif l == 'ChMO':
                        user_input.append(user_input[5]-user_input[0])
                    elif l == 'ChMH':
                        user_input.append(user_input[5]-user_input[1])
                    elif l == 'ChML':
                        user_input.append(user_input[5]-user_input[2])
                    elif l == 'ChMC':
                        user_input.append(user_input[5]-user_input[3])
                    elif l == 'ChMV':
                        user_input.append(user_input[5]-user_input[4])
                    elif l == 'OPH':
                        user_input.append(user_input[0]+user_input[1])
                    elif l == 'OPL':
                        user_input.append(user_input[0]+user_input[2])
                    elif l == 'OPC':
                        user_input.append(user_input[0]+user_input[3])
                    elif l == 'OPV':
                        user_input.append(user_input[0]+user_input[4])
                    elif l == 'OPCh':
                        user_input.append(user_input[0]+user_input[5])
                    elif l == 'HPO':
                        user_input.append(user_input[1]+user_input[0])
                    elif l == 'HPC':
                        user_input.append(user_input[1]+user_input[3])
                    elif l == 'HPV':
                        user_input.append(user_input[1]+user_input[4])
                    elif l == 'HPL':
                        user_input.append(user_input[1]+user_input[2])
                    elif l == 'HPCh':
                        user_input.append(user_input[1]+user_input[5])
                    elif l == 'LPO':
                        user_input.append(user_input[2]+user_input[0])
                    elif l == 'LPH':
                        user_input.append(user_input[2]+user_input[1])
                    elif l == 'LPC':
                        user_input.append(user_input[2]+user_input[3])
                    elif l == 'LPV':
                        user_input.append(user_input[2]+user_input[4])
                    elif l == 'LPCh':
                        user_input.append(user_input[2]+user_input[5])
                    elif l == 'CPO':
                        user_input.append(user_input[3]+user_input[0])
                    elif l == 'CPH':
                        user_input.append(user_input[3]+user_input[1])
                    elif l == 'CPL':
                        user_input.append(user_input[3]+user_input[2])
                    elif l == 'CPV':
                        user_input.append(user_input[3]+user_input[4])
                    elif l == 'CPCh':
                        user_input.append(user_input[3]+user_input[5])
                    elif l == 'VPO':
                        user_input.append(user_input[4]+user_input[0])
                    elif l == 'VPH':
                        user_input.append(user_input[4]+user_input[1])
                    elif l == 'VPL':
                        user_input.append(user_input[4]+user_input[2])
                    elif l == 'VPC':
                        user_input.append(user_input[4]+user_input[3])
                    elif l == 'VPCh':
                        user_input.append(user_input[4]+user_input[5])
                    elif l == 'ChPO':
                        user_input.append(user_input[5]+user_input[0])
                    elif l == 'ChPH':
                        user_input.append(user_input[5]+user_input[1])
                    elif l == 'ChPL':
                        user_input.append(user_input[5]+user_input[2])
                    elif l == 'ChPC':
                        user_input.append(user_input[5]+user_input[3])
                    elif l == 'ChPV':
                        user_input.append(user_input[5]+user_input[4])
                    elif l == 'ODH':
                        user_input.append(user_input[0]/user_input[1])
                    elif l == 'ODL':
                        user_input.append(user_input[0]/user_input[2])
                    elif l == 'ODC':
                        user_input.append(user_input[0]/user_input[3])
                    elif l == 'ODV':
                        user_input.append(user_input[0]/user_input[4])
                    elif l == 'HDO':
                        user_input.append(user_input[1]/user_input[0])
                    elif l == 'HDL':
                        user_input.append(user_input[1]/user_input[2])
                    elif l == 'HDC':
                        user_input.append(user_input[1]/user_input[3])
                    elif l == 'HDV':
                        user_input.append(user_input[1]/user_input[4])
                    elif l == 'LDO':
                        user_input.append(user_input[2]/user_input[0])
                    elif l == 'LDH':
                        user_input.append(user_input[2]/user_input[1])
                    elif l == 'LDC':
                        user_input.append(user_input[2]/user_input[3])
                    elif l == 'LDV':
                        user_input.append(user_input[2]/user_input[4])
                    elif l == 'VDO':
                        user_input.append(user_input[4]/user_input[0])
                    elif l == 'VDH':
                        user_input.append(user_input[4]/user_input[1])
                    elif l == 'VDL':
                        user_input.append(user_input[4]/user_input[2])
                    elif l == 'VDC':
                        user_input.append(user_input[4]/user_input[3])
                    elif l == 'ChDO':
                        user_input.append(user_input[5]/user_input[0])
                    elif l == 'ChDH':
                        user_input.append(user_input[5]/user_input[1])
                    elif l == 'ChDL':
                        user_input.append(user_input[5]/user_input[2])
                    elif l == 'ChDC':
                        user_input.append(user_input[5]/user_input[3])
                    elif l == 'ChDV':
                        user_input.append(user_input[5]/user_input[4])
                    elif l == 'OmH':
                        user_input.append(user_input[0]*user_input[1])
                    elif l == 'OmL':
                        user_input.append(user_input[0]*user_input[2])
                    elif l == 'OmC':
                        user_input.append(user_input[0]*user_input[3])
                    elif l == 'OmV':
                        user_input.append(user_input[0]*user_input[4])
                    elif l == 'OmCh':
                        user_input.append(user_input[0]*user_input[5])
                    elif l == 'HmC':
                        user_input.append(user_input[1]*user_input[3])
                    elif l == 'HmV':
                        user_input.append(user_input[1]*user_input[4])
                    elif l == 'HmCh':
                        user_input.append(user_input[1]*user_input[5])
                    elif l == 'LmH':
                        user_input.append(user_input[2]*user_input[1])
                    elif l == 'LmC':
                        user_input.append(user_input[2]*user_input[3])
                    elif l == 'LmV':
                        user_input.append(user_input[2]*user_input[4])
                    elif l == 'LmCh':
                        user_input.append(user_input[2]*user_input[5])
                    elif l == 'CmV':
                        user_input.append(user_input[3]*user_input[4])
                    elif l == 'CmCh':
                        user_input.append(user_input[3]*user_input[5])
                    elif l == 'VmCh':
                        user_input.append(user_input[4]*user_input[5])

                today_data = user_input

                # 입력값을 정규화
                today_data_normalized = scaler.transform([today_data])  # 2D 배열로 변환

                # 모델로 예측
                predicted_data = model.predict(np.array([today_data_normalized]))  # 3D 배열로 변환

                # 정규화 이전의 값을 출력
                predicted_data_original = scaler.inverse_transform(predicted_data.reshape(1, -1))

                predicted_data_original = predicted_data_original[0]  # 배열의 첫 번째 요소 추출
                float_value = predicted_data_original[5-unit_num]  # 종가상승률(원값 그대로 사용)
                integer_values = predicted_data_original.astype(int)  # 마지막 요소를 제외한 나머지 요소를 정수로 변환
                formatted_values = list(integer_values)
                formatted_values[5-unit_num] = float_value
                appenddata = pd.DataFrame({'시가':formatted_values[0],'최고가':formatted_values[1],'최저가':formatted_values[2],'종가':formatted_values[3],
                '판매량':formatted_values[4],'변동률':formatted_values[5],'추가열':selected_list[0]}, index=[0])
                lastdf = pd.concat([resultdf,appenddata], ignore_index=True)
                resultdf = lastdf
                model_json = model.to_json()
                with open("model.json", "w") as json_file:
                    json_file.write(model_json)
                model.save(f'010130.h5')
            selected_list = []
    # start_col_num += 1

# %%
import FinanceDataReader as fdr
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from keras.layers import Dense, Activation
from keras.layers import LSTM
from keras.models import Sequential
# Open, High, Low, Close, Volume, Change
resultdf = pd.DataFrame(columns=['시가','최고가','최저가','종가','판매량','변동률','추가열'])
max_num = 1# 사용할 특성열 수
col_list = ['DPR','IPC','VWCP','OMH','OML','OMV','OMC','HMO','HMC','HMV','HMCh','LMO','LMH','LMC','LMV','LMCh','CMO','CMH','CML','CMV','CMCh','VMO',
            'VMH','VML','VMC','VMCh','ChMO','ChMH','ChML','ChMC','ChMV','OPH','OPL','OPC','OPV','OPCh','HPO','HPC','HPV','HPL','HPCh','LPO','LPH',
            'LPC','LPV','LPCh','CPO','CPH','CPL','CPV','CPCh','VPO','VPH','VPL','VPC','VPCh','ChPO','ChPH','ChPL','ChPC','ChPV','ODH','ODL','ODC',
            'HDO','HDL','HDC','LDO','LDH','LDC','VDC','ChDC','OmH','OmL','OmC','OmV',
            'OmCh','HmC','HmV','HmCh','LmH','LmC','LmV','LmCh','CmV','CmCh','VmCh']
selected_list = []
start_col_num = 0
for i in col_list:
            s1 = fdr.DataReader('047810', start = '1960', end = '2023')
            df1 = pd.DataFrame(s1)
            df1 = df1.dropna()
    # for j in col_list[71:]:
    # for j in col_list[start_col_num+1:]:
        # for a in col_list[start_col_num+2:]:
        # for a in col_list[43:]:
            selected_list.append(i)
            # selected_list.append(j)
            # selected_list.append(a)
            print(i)
            if len(selected_list) == max_num:
                for k in selected_list:
                    if k == 'DPR':
                        df1['DPR'] = df1['High'] - df1['Low']
                    elif k == 'IPC':
                        df1['IPC'] = df1['Open'] - df1['Close']
                    elif k == 'VWCP':
                        df1['VWCP'] = df1['Volume'] * df1['Change']
                    elif k == 'IPRPV':
                        if 'DPR' in selected_list:
                            df1['IPRPV'] = df1['DPR']/df1['Volume']
                        else:
                            break
                    elif k == 'OMH':
                        df1['OMH'] = df1['Open'] - df1['High']
                    elif k == 'OML':
                        df1['OML'] = df1['Open'] - df1['Low']
                    elif k == 'OMV':
                        df1['OMV'] = df1['Open'] - df1['Volume']
                    elif k == 'OMC':
                        df1['OMC'] = df1['Open'] - df1['Change']
                    elif k == 'HMO':
                        df1['HMO'] = df1['High'] - df1['Open']
                    elif k == 'HMC':
                        df1['HMC'] = df1['High'] - df1['Close']
                    elif k == 'HMV':
                        df1['HMV'] = df1['High'] - df1['Volume']
                    elif k == 'HMCh':
                        df1['HMCh'] = df1['High'] - df1['Change']
                    elif k == 'LMO':
                        df1['LMO'] = df1['Low'] - df1['Open']
                    elif k == 'LMH':
                        df1['LMH'] = df1['Low'] - df1['High']
                    elif k == 'LMC':
                        df1['LMC'] = df1['Low'] - df1['Close']
                    elif k == 'LMV':
                        df1['LMV'] = df1['Low'] - df1['Volume']
                    elif k == 'LMCh':
                        df1['LMCh'] = df1['Low'] - df1['Change']
                    elif k == 'CMO':
                        df1['CMO'] = df1['Close'] - df1['Open']
                    elif k == 'CMH':
                        df1['CMH'] = df1['Close'] - df1['High']
                    elif k == 'CML':
                        df1['CML'] = df1['Close'] - df1['Low']
                    elif k == 'CMV':
                        df1['CMV'] = df1['Close'] - df1['Volume']
                    elif k == 'CMCh':
                        df1['CMCh'] = df1['Close'] - df1['Change']
                    elif k == 'VMO':
                        df1['VMO'] = df1['Volume'] - df1['Open']
                    elif k == 'VMH':
                        df1['VMH'] = df1['Volume'] - df1['High']
                    elif k == 'VML':
                        df1['VML'] = df1['Volume'] - df1['Low']
                    elif k == 'VMC':
                        df1['VMC'] = df1['Volume'] - df1['Close']
                    elif k == 'VMCh':
                        df1['VMCh'] = df1['Volume'] - df1['Change']
                    elif k == 'ChMO':
                        df1['ChMO'] = df1['Change'] - df1['Open']
                    elif k == 'ChMH':
                        df1['ChMH'] = df1['Change'] - df1['High']
                    elif k == 'ChML':
                        df1['ChML'] = df1['Change'] - df1['Low']
                    elif k == 'ChMC':
                        df1['ChMC'] = df1['Change'] - df1['Close']
                    elif k == 'ChMV':
                        df1['ChMV'] = df1['Change'] - df1['Volume']
                    elif k == 'OPH':
                        df1['OPH'] = df1['Open'] + df1['High']
                    elif k == 'OPL':
                        df1['OPL'] = df1['Open'] + df1['Low']
                    elif k == 'OPC':
                        df1['OPC'] = df1['Open'] + df1['Close']
                    elif k == 'OPV':
                        df1['OPV'] = df1['Open'] + df1['Volume']
                    elif k == 'OPCh':
                        df1['OPCh'] = df1['Open'] + df1['Change']
                    elif k == 'HPO':
                        df1['HPO'] = df1['High'] + df1['Open']
                    elif k == 'HPC':
                        df1['HPC'] = df1['High'] + df1['Close']
                    elif k == 'HPV':
                        df1['HPV'] = df1['High'] + df1['Volume']
                    elif k == 'HPL':
                        df1['HPL'] = df1['High'] + df1['Low']
                    elif k == 'HPCh':
                        df1['HPCh'] = df1['High'] + df1['Change']
                    elif k == 'LPO':
                        df1['LPO'] = df1['Low'] + df1['Open']
                    elif k == 'LPH':
                        df1['LPH'] = df1['Low'] + df1['High']
                    elif k == 'LPC':
                        df1['LPC'] = df1['Low'] + df1['Close']
                    elif k == 'LPV':
                        df1['LPV'] = df1['Low'] + df1['Volume']
                    elif k == 'LPCh':
                        df1['LPCh'] = df1['Low'] + df1['Change']
                    elif k == 'CPO':
                        df1['CPO'] = df1['Close'] + df1['Open']
                    elif k == 'CPH':
                        df1['CPH'] = df1['Close'] + df1['High']
                    elif k == 'CPL':
                        df1['CPL'] = df1['Close'] + df1['Low']
                    elif k == 'CPV':
                        df1['CPV'] = df1['Close'] + df1['Volume']
                    elif k == 'CPCh':
                        df1['CPCh'] = df1['Close'] + df1['Change']
                    elif k == 'VPO':
                        df1['VPO'] = df1['Volume'] + df1['Open']
                    elif k == 'VPH':
                        df1['VPH'] = df1['Volume'] + df1['High']
                    elif k == 'VPL':
                        df1['VPL'] = df1['Volume'] + df1['Low']
                    elif k == 'VPC':
                        df1['VPC'] = df1['Volume'] + df1['Close']
                    elif k == 'VPCh':
                        df1['VPCh'] = df1['Volume'] + df1['Change']
                    elif k == 'ChPO':
                        df1['ChPO'] = df1['Change'] + df1['Open']
                    elif k == 'ChPH':
                        df1['ChPH'] = df1['Change'] + df1['High']
                    elif k == 'ChPL':
                        df1['ChPL'] = df1['Change'] + df1['Low']
                    elif k == 'ChPC':
                        df1['ChPC'] = df1['Change'] + df1['Close']
                    elif k == 'ChPV':
                        df1['ChPV'] = df1['Change'] + df1['Volume']
                    elif k == 'ODH':
                        df1['ODH'] = df1['Open'] / df1['High']
                    elif k == 'ODL':
                        df1['ODL'] = df1['Open'] / df1['Low']
                    elif k == 'ODC':
                        df1['ODC'] = df1['Open'] / df1['Close']
                    elif k == 'ODV':
                        df1['ODV'] = df1['Open'] / df1['Volume']
                    elif k == 'HDO':
                        df1['HDO'] = df1['High'] / df1['Open']
                    elif k == 'HDL':
                        df1['HDL'] = df1['High'] / df1['Low']
                    elif k == 'HDC':
                        df1['HDC'] = df1['High'] / df1['Close']
                    elif k == 'HDV':
                        df1['HDV'] = df1['High'] / df1['Volume']
                    elif k == 'LDO':
                        df1['LDO'] = df1['Low'] / df1['Open']
                    elif k == 'LDH':
                        df1['LDH'] = df1['Low'] / df1['High']
                    elif k == 'LDC':
                        df1['LDC'] = df1['Low'] / df1['Close']
                    elif k == 'LDV':
                        df1['LDV'] = df1['Low'] / df1['Volume']
                    elif k == 'VDO':
                        df1['VDO'] = df1['Volume'] / df1['Open']
                    elif k == 'VDH':
                        df1['VDH'] = df1['Volume'] / df1['High']
                    elif k == 'VDL':
                        df1['VDL'] = df1['Volume'] / df1['Low']
                    elif k == 'VDC':
                        df1['VDC'] = df1['Volume'] / df1['Close']
                    elif k == 'ChDO':
                        df1['ChDO'] = df1['Change'] / df1['Open']
                    elif k == 'ChDH':
                        df1['ChDH'] = df1['Change'] / df1['High']
                    elif k == 'ChDL':
                        df1['ChDL'] = df1['Change'] / df1['Low']
                    elif k == 'ChDC':
                        df1['ChDC'] = df1['Change'] / df1['Close']
                    elif k == 'ChDV':
                        df1['ChDV'] = df1['Change'] / df1['Volume']
                    elif k == 'OmH':
                        df1['OmH'] = df1['Open'] * df1['High']
                    elif k == 'OmL':
                        df1['OmL'] = df1['Open'] * df1['Low']
                    elif k == 'OmC':
                        df1['OmC'] = df1['Open'] * df1['Close']
                    elif k == 'OmV':
                        df1['OmV'] = df1['Open'] * df1['Volume']
                    elif k == 'OmCh':
                        df1['OmCh'] = df1['Open'] * df1['Change']
                    elif k == 'HmC':
                        df1['HmC'] = df1['High'] * df1['Close']
                    elif k == 'HmV':
                        df1['HmV'] = df1['High'] * df1['Volume']
                    elif k == 'HmCh':
                        df1['HmCh'] = df1['High'] * df1['Change']
                    elif k == 'LmH':
                        df1['LmH'] = df1['Low'] * df1['High']
                    elif k == 'LmC':
                        df1['LmC'] = df1['Low'] * df1['Close']
                    elif k == 'LmV':
                        df1['LmV'] = df1['Low'] * df1['Volume']
                    elif k == 'LmCh':
                        df1['LmCh'] = df1['Low'] * df1['Change']
                    elif k == 'CmV':
                        df1['CmV'] = df1['Close'] * df1['Volume']
                    elif k == 'CmCh':
                        df1['CmCh'] = df1['Close'] * df1['Change']
                    elif k == 'VmCh':
                        df1['VmCh'] = df1['Volume'] * df1['Change']
                df1.to_csv('sk.csv')
                # CSV 파일을 불러옵니다.
                data = pd.read_csv('sk.csv')

                # 날짜(Dates) 열을 Datetime 형식으로 변환합니다.
                data['Date'] = pd.to_datetime(data['Date'])

                # 필요한 열을 추출합니다. (이 예에서는 'Open', 'High', 'Low', 'Close', 'Volume', 'Change' 열을 사용)
                use_list = ['Open', 'High', 'Low', 'Close', 'Volume', 'Change']
                for b in selected_list:
                    use_list.append(b)
                print(use_list)
                features = data[use_list]
                unit_num = len(use_list)

                # Min-Max 스케일링을 사용하여 데이터를 정규화합니다.
                scaler = MinMaxScaler()
                features_normalized = scaler.fit_transform(features)

                # 시계열 예측을 위해 데이터를 X와 y로 분리합니다.
                # X는 어제의 데이터, y는 오늘의 'Open', 'High', 'Low', 'Close', 'Volume', 'Change' 값을 나타냅니다.
                X, y = [], []

                look_back = 1  # 어제의 데이터를 사용
                for c in range(look_back, len(features_normalized)):
                    X.append(features_normalized[c - look_back:c])
                    y.append(features_normalized[c])

                X, y = np.array(X), np.array(y)

                # 데이터를 훈련 세트와 테스트 세트로 나눕니다.
                split_ratio = 0.8  # 예시로 80%를 훈련 데이터로 사용
                split_index = int(split_ratio * len(X))

                X_train, X_test = X[:split_index], X[split_index:]
                y_train, y_test = y[:split_index], y[split_index:]

                # 모델 생성
                model = Sequential()

                model.add(LSTM(
                    units=100,
                    input_shape=(X_train.shape[1], X_train.shape[2]),
                    return_sequences=True))
                model.add(LSTM(
                    100,
                    return_sequences=False))
                model.add(Dense(units=unit_num))  # 'Open', 'High', 'Low', 'Close', 'Volume', 'Change'에 대한 출력
                model.add(Activation('linear'))

                # 모델 컴파일
                model.compile(loss='mse', optimizer='adam')

                # 모델 학습
                model.fit(X_train, y_train, epochs=50, batch_size=64, validation_split=0.1)

                # 예측
                # 시가, 최고가, 최저가, 종가, 판매량,변동률
                user_input = [49200,49450,43600,44200,1364686,-0.105263158]
                for l in selected_list:
                    if l == 'DPR':
                        user_input.append(user_input[1]-user_input[2])
                    elif l == 'IPC':
                        user_input.append(user_input[0]-user_input[3])
                    elif l == 'VWCP':
                        user_input.append(user_input[4]*user_input[5])
                    elif l == 'IPRPV':
                        if 'DPR' in selected_list:
                            user_input.append(user_input[6]/user_input[4])
                    elif l == 'OMH':
                        user_input.append(user_input[0]-user_input[1])
                    elif l == 'OML':
                        user_input.append(user_input[0]-user_input[2])
                    elif l == 'OMV':
                        user_input.append(user_input[0]-user_input[4])
                    elif l == 'OMC':
                        user_input.append(user_input[0]-user_input[5])
                    elif l == 'HMO':
                        user_input.append(user_input[1]-user_input[0])
                    elif l == 'HMC':
                        user_input.append(user_input[1]-user_input[3])
                    elif l == 'HMV':
                        user_input.append(user_input[1]-user_input[4])
                    elif l == 'HMCh':
                        user_input.append(user_input[1]-user_input[5])
                    elif l == 'LMO':
                        user_input.append(user_input[2]-user_input[0])
                    elif l == 'LMH':
                        user_input.append(user_input[2]-user_input[1])
                    elif l == 'LMC':
                        user_input.append(user_input[2]-user_input[3])
                    elif l == 'LMV':
                        user_input.append(user_input[2]-user_input[4])
                    elif l == 'LMCh':
                        user_input.append(user_input[2]-user_input[5])
                    elif l == 'CMO':
                        user_input.append(user_input[3]-user_input[0])
                    elif l == 'CMH':
                        user_input.append(user_input[3]-user_input[1])
                    elif l == 'CML':
                        user_input.append(user_input[3]-user_input[2])
                    elif l == 'CMV':
                        user_input.append(user_input[3]-user_input[4])
                    elif l == 'CMCh':
                        user_input.append(user_input[3]-user_input[5])
                    elif l == 'VMO':
                        user_input.append(user_input[4]-user_input[0])
                    elif l == 'VMH':
                        user_input.append(user_input[4]-user_input[1])
                    elif l == 'VML':
                        user_input.append(user_input[4]-user_input[2])
                    elif l == 'VMC':
                        user_input.append(user_input[4]-user_input[3])
                    elif l == 'VMCh':
                        user_input.append(user_input[4]-user_input[5])
                    elif l == 'ChMO':
                        user_input.append(user_input[5]-user_input[0])
                    elif l == 'ChMH':
                        user_input.append(user_input[5]-user_input[1])
                    elif l == 'ChML':
                        user_input.append(user_input[5]-user_input[2])
                    elif l == 'ChMC':
                        user_input.append(user_input[5]-user_input[3])
                    elif l == 'ChMV':
                        user_input.append(user_input[5]-user_input[4])
                    elif l == 'OPH':
                        user_input.append(user_input[0]+user_input[1])
                    elif l == 'OPL':
                        user_input.append(user_input[0]+user_input[2])
                    elif l == 'OPC':
                        user_input.append(user_input[0]+user_input[3])
                    elif l == 'OPV':
                        user_input.append(user_input[0]+user_input[4])
                    elif l == 'OPCh':
                        user_input.append(user_input[0]+user_input[5])
                    elif l == 'HPO':
                        user_input.append(user_input[1]+user_input[0])
                    elif l == 'HPC':
                        user_input.append(user_input[1]+user_input[3])
                    elif l == 'HPV':
                        user_input.append(user_input[1]+user_input[4])
                    elif l == 'HPL':
                        user_input.append(user_input[1]+user_input[2])
                    elif l == 'HPCh':
                        user_input.append(user_input[1]+user_input[5])
                    elif l == 'LPO':
                        user_input.append(user_input[2]+user_input[0])
                    elif l == 'LPH':
                        user_input.append(user_input[2]+user_input[1])
                    elif l == 'LPC':
                        user_input.append(user_input[2]+user_input[3])
                    elif l == 'LPV':
                        user_input.append(user_input[2]+user_input[4])
                    elif l == 'LPCh':
                        user_input.append(user_input[2]+user_input[5])
                    elif l == 'CPO':
                        user_input.append(user_input[3]+user_input[0])
                    elif l == 'CPH':
                        user_input.append(user_input[3]+user_input[1])
                    elif l == 'CPL':
                        user_input.append(user_input[3]+user_input[2])
                    elif l == 'CPV':
                        user_input.append(user_input[3]+user_input[4])
                    elif l == 'CPCh':
                        user_input.append(user_input[3]+user_input[5])
                    elif l == 'VPO':
                        user_input.append(user_input[4]+user_input[0])
                    elif l == 'VPH':
                        user_input.append(user_input[4]+user_input[1])
                    elif l == 'VPL':
                        user_input.append(user_input[4]+user_input[2])
                    elif l == 'VPC':
                        user_input.append(user_input[4]+user_input[3])
                    elif l == 'VPCh':
                        user_input.append(user_input[4]+user_input[5])
                    elif l == 'ChPO':
                        user_input.append(user_input[5]+user_input[0])
                    elif l == 'ChPH':
                        user_input.append(user_input[5]+user_input[1])
                    elif l == 'ChPL':
                        user_input.append(user_input[5]+user_input[2])
                    elif l == 'ChPC':
                        user_input.append(user_input[5]+user_input[3])
                    elif l == 'ChPV':
                        user_input.append(user_input[5]+user_input[4])
                    elif l == 'ODH':
                        user_input.append(user_input[0]/user_input[1])
                    elif l == 'ODL':
                        user_input.append(user_input[0]/user_input[2])
                    elif l == 'ODC':
                        user_input.append(user_input[0]/user_input[3])
                    elif l == 'ODV':
                        user_input.append(user_input[0]/user_input[4])
                    elif l == 'HDO':
                        user_input.append(user_input[1]/user_input[0])
                    elif l == 'HDL':
                        user_input.append(user_input[1]/user_input[2])
                    elif l == 'HDC':
                        user_input.append(user_input[1]/user_input[3])
                    elif l == 'HDV':
                        user_input.append(user_input[1]/user_input[4])
                    elif l == 'LDO':
                        user_input.append(user_input[2]/user_input[0])
                    elif l == 'LDH':
                        user_input.append(user_input[2]/user_input[1])
                    elif l == 'LDC':
                        user_input.append(user_input[2]/user_input[3])
                    elif l == 'LDV':
                        user_input.append(user_input[2]/user_input[4])
                    elif l == 'VDO':
                        user_input.append(user_input[4]/user_input[0])
                    elif l == 'VDH':
                        user_input.append(user_input[4]/user_input[1])
                    elif l == 'VDL':
                        user_input.append(user_input[4]/user_input[2])
                    elif l == 'VDC':
                        user_input.append(user_input[4]/user_input[3])
                    elif l == 'ChDO':
                        user_input.append(user_input[5]/user_input[0])
                    elif l == 'ChDH':
                        user_input.append(user_input[5]/user_input[1])
                    elif l == 'ChDL':
                        user_input.append(user_input[5]/user_input[2])
                    elif l == 'ChDC':
                        user_input.append(user_input[5]/user_input[3])
                    elif l == 'ChDV':
                        user_input.append(user_input[5]/user_input[4])
                    elif l == 'OmH':
                        user_input.append(user_input[0]*user_input[1])
                    elif l == 'OmL':
                        user_input.append(user_input[0]*user_input[2])
                    elif l == 'OmC':
                        user_input.append(user_input[0]*user_input[3])
                    elif l == 'OmV':
                        user_input.append(user_input[0]*user_input[4])
                    elif l == 'OmCh':
                        user_input.append(user_input[0]*user_input[5])
                    elif l == 'HmC':
                        user_input.append(user_input[1]*user_input[3])
                    elif l == 'HmV':
                        user_input.append(user_input[1]*user_input[4])
                    elif l == 'HmCh':
                        user_input.append(user_input[1]*user_input[5])
                    elif l == 'LmH':
                        user_input.append(user_input[2]*user_input[1])
                    elif l == 'LmC':
                        user_input.append(user_input[2]*user_input[3])
                    elif l == 'LmV':
                        user_input.append(user_input[2]*user_input[4])
                    elif l == 'LmCh':
                        user_input.append(user_input[2]*user_input[5])
                    elif l == 'CmV':
                        user_input.append(user_input[3]*user_input[4])
                    elif l == 'CmCh':
                        user_input.append(user_input[3]*user_input[5])
                    elif l == 'VmCh':
                        user_input.append(user_input[4]*user_input[5])

                today_data = user_input

                # 입력값을 정규화
                today_data_normalized = scaler.transform([today_data])  # 2D 배열로 변환

                # 모델로 예측
                predicted_data = model.predict(np.array([today_data_normalized]))  # 3D 배열로 변환

                # 정규화 이전의 값을 출력
                predicted_data_original = scaler.inverse_transform(predicted_data.reshape(1, -1))

                predicted_data_original = predicted_data_original[0]  # 배열의 첫 번째 요소 추출
                float_value = predicted_data_original[5-unit_num]  # 종가상승률(원값 그대로 사용)
                integer_values = predicted_data_original.astype(int)  # 마지막 요소를 제외한 나머지 요소를 정수로 변환
                formatted_values = list(integer_values)
                formatted_values[5-unit_num] = float_value
                appenddata = pd.DataFrame({'시가':formatted_values[0],'최고가':formatted_values[1],'최저가':formatted_values[2],'종가':formatted_values[3],
                '판매량':formatted_values[4],'변동률':formatted_values[5],'추가열':selected_list[0]}, index=[0])
                lastdf = pd.concat([resultdf,appenddata], ignore_index=True)
                resultdf = lastdf
                model.save_weights(f'한국항공우주(047810){selected_list[0]}.h5')
            selected_list = []
    # start_col_num += 1

# %%
resultdf.to_csv('한국항공우주 1번결과.csv')
